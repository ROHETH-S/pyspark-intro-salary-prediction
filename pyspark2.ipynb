# %%
pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285398 sha256=106db4b5643eee25a75733d32cc117d4a226d1fc2d78041ca3c5cfc035338677
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('data1').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://b170fd3c7344:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>data</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
### read the dataset
df_pyspark=spark.read.option('header', 'true').csv('data1.csv',inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +-------+---+----------+
# |   Name|age|experience|
# +-------+---+----------+
# | roheth| 21|         5|
# |roshaan| 21|         5|
# |   banu| 25|        10|
# +-------+---+----------+

# %%
df_pyspark.printSchema()
# to get datatype
# every column will be default as string, unit 'inferSchema=True' is given
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- experience: integer (nullable = true)

# %%
### read the dataset
# heade=true is given other wise default value will given as heading
df_pyspark=spark.read.csv('data1.csv',header=True,inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +-------+---+----------+
# |   Name|age|experience|
# +-------+---+----------+
# | roheth| 21|         5|
# |roshaan| 21|         5|
# |   banu| 25|        10|
# +-------+---+----------+

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.columns
# Out:
# ['Name', 'age', 'experience']

# %%
df_pyspark.select('Name')
# Out:
# DataFrame[Name: string]

# %%
df_pyspark.select('Name').show()
# Out:
# +-------+
# |   Name|
# +-------+
# | roheth|
# |roshaan|
# |   banu|
# +-------+

# %%
df_pyspark.select(['Name', 'experience'])
# Out:
# DataFrame[Name: string, experience: int]

# %%
df_pyspark.select(['Name', 'experience']).show()
# Out:
# +-------+----------+
# |   Name|experience|
# +-------+----------+
# | roheth|         5|
# |roshaan|         5|
# |   banu|        10|
# +-------+----------+

# %%
df_pyspark['Name']
# Out:
# Column<'Name'>

# %%
df_pyspark.dtypes
# Out:
# [('Name', 'string'), ('age', 'int'), ('experience', 'int')]

# %%
df_pyspark.describe().show()
# mean of string will be null
# Out:
# +-------+-------+------------------+------------------+
# |summary|   Name|               age|        experience|
# +-------+-------+------------------+------------------+
# |  count|      3|                 3|                 3|
# |   mean|   null|22.333333333333332| 6.666666666666667|
# | stddev|   null|2.3094010767585034|2.8867513459481287|
# |    min|   banu|                21|                 5|
# |    max|roshaan|                25|                10|
# +-------+-------+------------------+------------------+

# %%
### adding columns in data frame
df_pyspark=df_pyspark.withColumn('Exp after 2 years',df_pyspark['experience']+2)

# %%
df_pyspark.show()
# Out:
# +-------+---+----------+-----------------+
# |   Name|age|experience|Exp after 2 years|
# +-------+---+----------+-----------------+
# | roheth| 21|         5|                7|
# |roshaan| 21|         5|                7|
# |   banu| 25|        10|               12|
# +-------+---+----------+-----------------+

# %%
### droping cloumns
df_pyspark=df_pyspark.drop('Exp after 2 years')

# %%
df_pyspark.show()
# Out:
# +-------+---+----------+
# |   Name|age|experience|
# +-------+---+----------+
# | roheth| 21|         5|
# |roshaan| 21|         5|
# |   banu| 25|        10|
# +-------+---+----------+

# %%
### rename the coulumn
df_pyspark=df_pyspark.withColumnRenamed('Name', 'New Name')

# %%
df_pyspark=df_pyspark.withColumnRenamed('Name', 'New Name').show()
# Out:
# +--------+---+----------+
# |New Name|age|experience|
# +--------+---+----------+
# |  roheth| 21|         5|
# | roshaan| 21|         5|
# |    banu| 25|        10|
# +--------+---+----------+
