# %%
pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.4.1.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285398 sha256=c3c4b14684937d932418af9a45a6674060d45363420323c39035bc9d2a4f62d9
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.4.1

# %%
import pyspark

# %%
import pandas as pd
pd.read_csv('data.csv')
# Out:
#       Name  age
# 0   roheth   21
# 1  roshaan   21
# 2     banu   25

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('practise').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://15ae1a50ee11:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.csv('data.csv')

# %%
df_pyspark
# Out:
# DataFrame[_c0: string, _c1: string]

# %%
df_pyspark.show()
# Out:
# +-------+---+
# |    _c0|_c1|
# +-------+---+
# |   Name|age|
# | roheth| 21|
# |roshaan| 21|
# |   banu| 25|
# +-------+---+

# %%
spark.read.option('header','true').csv('data.csv')
# Out:
# DataFrame[Name: string, age: string]

# %%
df_pyspark=spark.read.option('header','true').csv('data.csv')

# %%
df_pyspark.show()
# Out:
# +-------+---+
# |   Name|age|
# +-------+---+
# | roheth| 21|
# |roshaan| 21|
# |   banu| 25|
# +-------+---+

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: string (nullable = true)

# %%
df_pyspark.head(2)
# Out:
# [Row(Name='roheth', age='21'), Row(Name='roshaan', age='21')]
